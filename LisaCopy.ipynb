# %%
for dataset in ['imdb'] :
    # %run train_and_run_experiments_bc.py --dataset {dataset} --data_dir='.' --output_dir='outputs/' --attention=tanh

# %%
for dataset in ['imdb'] :
    # %run train_and_run_experiments_bc.py --dataset {dataset} --data_dir='.' --output_dir='outputs/' --attention=dot

# %%
for dataset in ['Anemia'] :
    # %run train_and_run_experiments_bc.py --dataset {dataset} --data_dir='.' --output_dir='outputs/' --attention=tanh

# %%
for dataset in ['Anemia'] :
    # %run train_and_run_experiments_bc.py --dataset {dataset} --data_dir='.' --output_dir='outputs/' --attention=dot

# %%
for dataset in ['babi_1', 'babi_2', 'babi_3'] :
    # %run train_and_run_experiments_qa.py --dataset {dataset} --data_dir='.' --output_dir='outputs/' --attention=tanh
# Out:
# /home/sarthak/anaconda3/lib/python3.7/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator CountVectorizer from version 0.20.0 when using version 0.20.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# INFO - 2019-04-01 12:12:47,005 - instantiating class <class 'Transparency.model.modules.Encoder.Encoder'> from params {'vocab_size': 40, 'embed_size': 50, 'kernel_sizes': (1, 3, 5, 7), 'hidden_size': 64, 'activation': 'relu', 'type': 'cnn', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:12:47,006 - type = cnn
# INFO - 2019-04-01 12:12:47,006 - instantiating class <class 'Transparency.model.modules.Encoder.EncoderCNN'> from params {'vocab_size': 40, 'embed_size': 50, 'kernel_sizes': (1, 3, 5, 7), 'hidden_size': 64, 'activation': 'relu', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:12:47,131 - vocab_size = 40
# INFO - 2019-04-01 12:12:47,132 - embed_size = 50
# INFO - 2019-04-01 12:12:47,132 - hidden_size = 64
# INFO - 2019-04-01 12:12:47,132 - kernel_sizes = (1, 3, 5, 7)
# INFO - 2019-04-01 12:12:47,133 - activation = relu
# INFO - 2019-04-01 12:12:47,133 - pre_embed = None
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# INFO - 2019-04-01 12:12:48,104 - instantiating class <class 'Transparency.model.modules.Encoder.Encoder'> from params {'vocab_size': 40, 'embed_size': 50, 'kernel_sizes': (1, 3, 5, 7), 'hidden_size': 64, 'activation': 'relu', 'type': 'cnn', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:12:48,105 - type = cnn
# INFO - 2019-04-01 12:12:48,105 - instantiating class <class 'Transparency.model.modules.Encoder.EncoderCNN'> from params {'vocab_size': 40, 'embed_size': 50, 'kernel_sizes': (1, 3, 5, 7), 'hidden_size': 64, 'activation': 'relu', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:12:48,106 - vocab_size = 40
# INFO - 2019-04-01 12:12:48,106 - embed_size = 50
# INFO - 2019-04-01 12:12:48,107 - hidden_size = 64
# INFO - 2019-04-01 12:12:48,107 - kernel_sizes = (1, 3, 5, 7)
# INFO - 2019-04-01 12:12:48,107 - activation = relu
# INFO - 2019-04-01 12:12:48,108 - pre_embed = None
# INFO - 2019-04-01 12:12:48,110 - instantiating class <class 'Transparency.model.modules.Decoder.AttnDecoderQA'> from params {'attention': {'type': 'tanh_qa'}, 'output_size': 36, 'hidden_size': 256} and extras {}
# INFO - 2019-04-01 12:12:48,110 - hidden_size = 256
# INFO - 2019-04-01 12:12:48,111 - output_size = 36
# INFO - 2019-04-01 12:12:48,111 - use_attention = True
# INFO - 2019-04-01 12:12:48,111 - regularizer_attention = None
# INFO - 2019-04-01 12:12:48,112 - instantiating class <class 'Transparency.model.modules.Attention.Attention'> from params <allennlp.common.params.Params object at 0x7f3ee4b65438> and extras {}
# INFO - 2019-04-01 12:12:48,113 - attention.type = tanh_qa
# INFO - 2019-04-01 12:12:48,113 - type = tanh_qa
# INFO - 2019-04-01 12:12:48,113 - instantiating class <class 'Transparency.model.modules.Attention.TanhQAAttention'> from params <allennlp.common.params.Params object at 0x7f3ee4b65438> and extras {}
# INFO - 2019-04-01 12:12:48,114 - attention.hidden_size = 256
# INFO - 2019-04-01 12:12:48,114 - hidden_size = 256
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.481}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.481
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.52}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.52
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.522}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.522
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.52}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.52
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.531}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.531
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.537}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.537
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.56}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.56
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.531}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.531
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.527}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.527
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.546}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.546
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.536}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.536
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.552}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.552
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.56}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.56
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.546}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.546
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.558}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.558
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.564}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.564
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.562}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.562
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.537}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.537
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.547}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.547
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.542}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.542
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.545}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.545
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.541}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.541
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.53}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.53
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.557}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.557
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.544}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.544
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.558}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.558
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.559}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.559
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.548}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.548
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.543}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.543
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.547}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.547
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.54}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.54
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.538}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.538
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.566}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.566
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.592}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.592
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.581}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.581
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.581}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.581
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.588}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.588
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.583}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.583
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.596}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.596
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.585}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.585
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.604}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.604
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.603}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.603
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.619}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.619
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.628}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.628
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.698}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.698
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.725}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.725
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.727}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.727
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.753}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.753
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.787}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.787
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.793}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.793
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.816}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.816
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.824}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.824
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.841}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.841
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.822}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.822
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.847}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.847
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.848}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.848
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.843}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.843
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.854}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.854
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.852}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.852
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.858}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.858
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.865}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.865
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.846}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.846
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.862}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.862
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.862}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.862
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.858}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.858
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.852}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.852
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.874}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.874
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.863}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.863
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.851}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.851
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.864}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.864
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.867}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.867
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.864}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.864
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.865}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.865
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.864}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.864
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.873}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.873
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.863}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.863
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.864}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.864
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.863}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.863
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.866}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.866
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.868}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.868
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.869}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.869
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.867}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.867
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.868}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.868
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.863}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.863
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.861}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.861
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.862}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.862
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.869}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.869
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.871}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.871
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.87}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.87
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.872}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.872
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.869}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.869
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.872}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.872
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.871}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.871
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.868}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.868
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.873}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.873
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.874}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.874
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.87}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.87
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.874}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.874
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.867}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.867
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.867}
# Empty DataFrame
# Columns: []
# Index: []
# INFO - 2019-04-01 12:16:14,589 - instantiating class <class 'Transparency.model.modules.Encoder.Encoder'> from params {'vocab_size': 40, 'embed_size': 50, 'kernel_sizes': [1, 3, 5, 7], 'hidden_size': 64, 'activation': 'relu', 'type': 'cnn', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:16:14,589 - type = cnn
# INFO - 2019-04-01 12:16:14,590 - instantiating class <class 'Transparency.model.modules.Encoder.EncoderCNN'> from params {'vocab_size': 40, 'embed_size': 50, 'kernel_sizes': [1, 3, 5, 7], 'hidden_size': 64, 'activation': 'relu', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:16:14,590 - vocab_size = 40
# INFO - 2019-04-01 12:16:14,590 - embed_size = 50
# INFO - 2019-04-01 12:16:14,591 - hidden_size = 64
# INFO - 2019-04-01 12:16:14,591 - kernel_sizes = [1, 3, 5, 7]
# INFO - 2019-04-01 12:16:14,592 - activation = relu
# INFO - 2019-04-01 12:16:14,592 - pre_embed = None
# INFO - 2019-04-01 12:16:14,594 - instantiating class <class 'Transparency.model.modules.Encoder.Encoder'> from params {'vocab_size': 40, 'embed_size': 50, 'kernel_sizes': [1, 3, 5, 7], 'hidden_size': 64, 'activation': 'relu', 'type': 'cnn', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:16:14,595 - type = cnn
# INFO - 2019-04-01 12:16:14,595 - instantiating class <class 'Transparency.model.modules.Encoder.EncoderCNN'> from params {'vocab_size': 40, 'embed_size': 50, 'kernel_sizes': [1, 3, 5, 7], 'hidden_size': 64, 'activation': 'relu', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:16:14,596 - vocab_size = 40
# INFO - 2019-04-01 12:16:14,596 - embed_size = 50
# INFO - 2019-04-01 12:16:14,596 - hidden_size = 64
# INFO - 2019-04-01 12:16:14,597 - kernel_sizes = [1, 3, 5, 7]
# INFO - 2019-04-01 12:16:14,597 - activation = relu
# INFO - 2019-04-01 12:16:14,597 - pre_embed = None
# INFO - 2019-04-01 12:16:14,600 - instantiating class <class 'Transparency.model.modules.Decoder.AttnDecoderQA'> from params {'attention': {'type': 'tanh_qa'}, 'output_size': 36, 'hidden_size': 256} and extras {}
# INFO - 2019-04-01 12:16:14,600 - hidden_size = 256
# INFO - 2019-04-01 12:16:14,601 - output_size = 36
# INFO - 2019-04-01 12:16:14,601 - use_attention = True
# INFO - 2019-04-01 12:16:14,601 - regularizer_attention = None
# INFO - 2019-04-01 12:16:14,602 - instantiating class <class 'Transparency.model.modules.Attention.Attention'> from params <allennlp.common.params.Params object at 0x7f3ee53b35c0> and extras {}
# INFO - 2019-04-01 12:16:14,603 - attention.type = tanh_qa
# INFO - 2019-04-01 12:16:14,603 - type = tanh_qa
# INFO - 2019-04-01 12:16:14,604 - instantiating class <class 'Transparency.model.modules.Attention.TanhQAAttention'> from params <allennlp.common.params.Params object at 0x7f3ee53b35c0> and extras {}
# INFO - 2019-04-01 12:16:14,604 - attention.hidden_size = 256
# INFO - 2019-04-01 12:16:14,605 - hidden_size = 256
# Model not saved on  accuracy 0.867
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.874}
# Empty DataFrame
# Columns: []
# Index: []
# INFO - 2019-04-01 12:16:14,724 - instantiating class <class 'Transparency.model.modules.Encoder.Encoder'> from params {'vocab_size': 40, 'embed_size': 50, 'projection': True, 'hidden_size': 128, 'activation': 'tanh', 'type': 'average', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:16:14,724 - type = average
# INFO - 2019-04-01 12:16:14,725 - instantiating class <class 'Transparency.model.modules.Encoder.EncoderAverage'> from params {'vocab_size': 40, 'embed_size': 50, 'projection': True, 'hidden_size': 128, 'activation': 'tanh', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:16:14,725 - vocab_size = 40
# INFO - 2019-04-01 12:16:14,725 - embed_size = 50
# INFO - 2019-04-01 12:16:14,726 - projection = True
# INFO - 2019-04-01 12:16:14,726 - hidden_size = 128
# INFO - 2019-04-01 12:16:14,726 - activation = tanh
# INFO - 2019-04-01 12:16:14,727 - pre_embed = None
# INFO - 2019-04-01 12:16:14,728 - instantiating class <class 'Transparency.model.modules.Encoder.Encoder'> from params {'vocab_size': 40, 'embed_size': 50, 'projection': True, 'hidden_size': 128, 'activation': 'tanh', 'type': 'average', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:16:14,729 - type = average
# INFO - 2019-04-01 12:16:14,729 - instantiating class <class 'Transparency.model.modules.Encoder.EncoderAverage'> from params {'vocab_size': 40, 'embed_size': 50, 'projection': True, 'hidden_size': 128, 'activation': 'tanh', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:16:14,729 - vocab_size = 40
# INFO - 2019-04-01 12:16:14,730 - embed_size = 50
# INFO - 2019-04-01 12:16:14,730 - projection = True
# INFO - 2019-04-01 12:16:14,730 - hidden_size = 128
# INFO - 2019-04-01 12:16:14,730 - activation = tanh
# INFO - 2019-04-01 12:16:14,731 - pre_embed = None
# INFO - 2019-04-01 12:16:14,732 - instantiating class <class 'Transparency.model.modules.Decoder.AttnDecoderQA'> from params {'attention': {'type': 'tanh_qa'}, 'output_size': 36, 'hidden_size': 128} and extras {}
# INFO - 2019-04-01 12:16:14,733 - hidden_size = 128
# INFO - 2019-04-01 12:16:14,733 - output_size = 36
# INFO - 2019-04-01 12:16:14,734 - use_attention = True
# INFO - 2019-04-01 12:16:14,734 - regularizer_attention = None
# INFO - 2019-04-01 12:16:14,735 - instantiating class <class 'Transparency.model.modules.Attention.Attention'> from params <allennlp.common.params.Params object at 0x7f3ee4c0cef0> and extras {}
# INFO - 2019-04-01 12:16:14,736 - attention.type = tanh_qa
# INFO - 2019-04-01 12:16:14,736 - type = tanh_qa
# INFO - 2019-04-01 12:16:14,736 - instantiating class <class 'Transparency.model.modules.Attention.TanhQAAttention'> from params <allennlp.common.params.Params object at 0x7f3ee4c0cef0> and extras {}
# INFO - 2019-04-01 12:16:14,737 - attention.hidden_size = 128
# INFO - 2019-04-01 12:16:14,737 - hidden_size = 128
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.149}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.149
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.154}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.154
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.171}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.171
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.154}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.154
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.157}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.157
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.182}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.182
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.348}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.348
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.387}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.387
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.377}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.377
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.376}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.376
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.389}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.389
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.384}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.384
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.392}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.392
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.372}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.372
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.382}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.382
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.377}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.377
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.403}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.403
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.382}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.382
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.382}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.382
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.39}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.39
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.391}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.391
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.391}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.391
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.396}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.396
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.378}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.378
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.396}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.396
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.395}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.395
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.409}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.409
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.41}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.41
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.414}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.414
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.43}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.43
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.439}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.439
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.431}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.431
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.43}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.43
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.424}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.424
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.406}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.406
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.419}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.419
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.435}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.435
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.415}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.415
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.42}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.42
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.425}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.425
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.418}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.418
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.423}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.423
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.426}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.426
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.412}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.412
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.417}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.417
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.413}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.413
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.423}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.423
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.434}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.434
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.409}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.409
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.416}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.416
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.403}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.403
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.415}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.415
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.417}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.417
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.429}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.429
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.441}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.441
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.415}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.415
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.421}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.421
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.432}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.432
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.414}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.414
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.434}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.434
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.41}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.41
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.403}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.403
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.425}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.425
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.423}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.423
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.426}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.426
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.427}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.427
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.416}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.416
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.412}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.412
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.413}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.413
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.406}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.406
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.416}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.416
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.411}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.411
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.408}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.408
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.414}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.414
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.42}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.42
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.395}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.395
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.415}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.415
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.411}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.411
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.415}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.415
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.422}
# ...
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.336}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.336
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.333}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.333
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.339}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.339
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.338}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.338
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.335}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.335
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.335}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.335
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.348}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.348
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.335}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.335
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.344}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.344
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.334}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.334
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.333}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.333
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.335}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.335
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.32}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.32
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.351}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.351
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.35}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.35
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.349}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.349
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.342}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.342
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.348}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.348
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.336}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.336
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.341}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.341
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.354}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.354
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.345}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.345
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.341}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.341
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.337}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.337
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.336}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.336
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.348}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.348
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.361}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.361
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.333}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.333
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.347}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.347
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.353}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.353
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.333}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.333
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.332}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.332
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.336}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.336
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.343}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.343
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.326}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.326
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.336}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.336
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.336}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.336
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.347}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.347
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.335}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.335
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.344}
# Empty DataFrame
# Columns: []
# Index: []
# INFO - 2019-04-01 12:30:17,328 - instantiating class <class 'Transparency.model.modules.Encoder.Encoder'> from params {'vocab_size': 40, 'embed_size': 50, 'projection': True, 'hidden_size': 128, 'activation': 'tanh', 'type': 'average', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:30:17,328 - type = average
# INFO - 2019-04-01 12:30:17,329 - instantiating class <class 'Transparency.model.modules.Encoder.EncoderAverage'> from params {'vocab_size': 40, 'embed_size': 50, 'projection': True, 'hidden_size': 128, 'activation': 'tanh', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:30:17,329 - vocab_size = 40
# INFO - 2019-04-01 12:30:17,330 - embed_size = 50
# INFO - 2019-04-01 12:30:17,330 - projection = True
# INFO - 2019-04-01 12:30:17,330 - hidden_size = 128
# INFO - 2019-04-01 12:30:17,331 - activation = tanh
# INFO - 2019-04-01 12:30:17,331 - pre_embed = None
# INFO - 2019-04-01 12:30:17,332 - instantiating class <class 'Transparency.model.modules.Encoder.Encoder'> from params {'vocab_size': 40, 'embed_size': 50, 'projection': True, 'hidden_size': 128, 'activation': 'tanh', 'type': 'average', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:30:17,333 - type = average
# INFO - 2019-04-01 12:30:17,333 - instantiating class <class 'Transparency.model.modules.Encoder.EncoderAverage'> from params {'vocab_size': 40, 'embed_size': 50, 'projection': True, 'hidden_size': 128, 'activation': 'tanh', 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:30:17,333 - vocab_size = 40
# INFO - 2019-04-01 12:30:17,334 - embed_size = 50
# INFO - 2019-04-01 12:30:17,334 - projection = True
# INFO - 2019-04-01 12:30:17,334 - hidden_size = 128
# INFO - 2019-04-01 12:30:17,335 - activation = tanh
# INFO - 2019-04-01 12:30:17,335 - pre_embed = None
# INFO - 2019-04-01 12:30:17,337 - instantiating class <class 'Transparency.model.modules.Decoder.AttnDecoderQA'> from params {'attention': {'type': 'tanh_qa'}, 'output_size': 36, 'hidden_size': 128} and extras {}
# INFO - 2019-04-01 12:30:17,337 - hidden_size = 128
# INFO - 2019-04-01 12:30:17,338 - output_size = 36
# INFO - 2019-04-01 12:30:17,338 - use_attention = True
# INFO - 2019-04-01 12:30:17,338 - regularizer_attention = None
# INFO - 2019-04-01 12:30:17,339 - instantiating class <class 'Transparency.model.modules.Attention.Attention'> from params <allennlp.common.params.Params object at 0x7f3ee5983f28> and extras {}
# INFO - 2019-04-01 12:30:17,340 - attention.type = tanh_qa
# INFO - 2019-04-01 12:30:17,340 - type = tanh_qa
# INFO - 2019-04-01 12:30:17,340 - instantiating class <class 'Transparency.model.modules.Attention.TanhQAAttention'> from params <allennlp.common.params.Params object at 0x7f3ee5983f28> and extras {}
# INFO - 2019-04-01 12:30:17,341 - attention.hidden_size = 128
# INFO - 2019-04-01 12:30:17,341 - hidden_size = 128
# Model not saved on  accuracy 0.344
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.361}
# Empty DataFrame
# Columns: []
# Index: []
# INFO - 2019-04-01 12:30:17,422 - instantiating class <class 'Transparency.model.modules.Encoder.Encoder'> from params {'vocab_size': 40, 'embed_size': 50, 'type': 'rnn', 'hidden_size': 128, 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:30:17,423 - type = rnn
# INFO - 2019-04-01 12:30:17,423 - instantiating class <class 'Transparency.model.modules.Encoder.EncoderRNN'> from params {'vocab_size': 40, 'embed_size': 50, 'hidden_size': 128, 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:30:17,424 - vocab_size = 40
# INFO - 2019-04-01 12:30:17,424 - embed_size = 50
# INFO - 2019-04-01 12:30:17,424 - hidden_size = 128
# INFO - 2019-04-01 12:30:17,425 - pre_embed = None
# INFO - 2019-04-01 12:30:17,427 - instantiating class <class 'Transparency.model.modules.Encoder.Encoder'> from params {'vocab_size': 40, 'embed_size': 50, 'type': 'rnn', 'hidden_size': 128, 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:30:17,427 - type = rnn
# INFO - 2019-04-01 12:30:17,428 - instantiating class <class 'Transparency.model.modules.Encoder.EncoderRNN'> from params {'vocab_size': 40, 'embed_size': 50, 'hidden_size': 128, 'pre_embed': None} and extras {}
# INFO - 2019-04-01 12:30:17,428 - vocab_size = 40
# INFO - 2019-04-01 12:30:17,429 - embed_size = 50
# INFO - 2019-04-01 12:30:17,429 - hidden_size = 128
# INFO - 2019-04-01 12:30:17,429 - pre_embed = None
# INFO - 2019-04-01 12:30:17,432 - instantiating class <class 'Transparency.model.modules.Decoder.AttnDecoderQA'> from params {'attention': {'type': 'tanh_qa'}, 'output_size': 36, 'hidden_size': 256} and extras {}
# INFO - 2019-04-01 12:30:17,432 - hidden_size = 256
# INFO - 2019-04-01 12:30:17,432 - output_size = 36
# INFO - 2019-04-01 12:30:17,433 - use_attention = True
# INFO - 2019-04-01 12:30:17,433 - regularizer_attention = None
# INFO - 2019-04-01 12:30:17,434 - instantiating class <class 'Transparency.model.modules.Attention.Attention'> from params <allennlp.common.params.Params object at 0x7f3ee443bac8> and extras {}
# INFO - 2019-04-01 12:30:17,435 - attention.type = tanh_qa
# INFO - 2019-04-01 12:30:17,435 - type = tanh_qa
# INFO - 2019-04-01 12:30:17,435 - instantiating class <class 'Transparency.model.modules.Attention.TanhQAAttention'> from params <allennlp.common.params.Params object at 0x7f3ee443bac8> and extras {}
# INFO - 2019-04-01 12:30:17,436 - attention.hidden_size = 256
# INFO - 2019-04-01 12:30:17,436 - hidden_size = 256
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.167}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.167
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.165}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.165
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.187}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.187
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.19}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.19
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.184}
# Empty DataFrame
# Columns: []
# Index: []
# Model not saved on  accuracy 0.184
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.222}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.222
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.284}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.284
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.393}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.393
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))
# {'accuracy': 0.469}
# Empty DataFrame
# Columns: []
# Index: []
# Model Saved on  accuracy 0.469
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
